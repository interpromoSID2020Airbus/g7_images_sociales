# %%
"""
created: Mon Jan 13 15:20:59 2020
Group 7
created by : L.D
"""
# Out:
# created: Mon Jan 13 15:20:59 2020

# %%
import pandas as pd
import numpy as np
import os
from shutil import copyfile
from keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import keras
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation,Flatten
from keras.layers import Conv2D, MaxPooling2D, InputLayer, ReLU
from keras.optimizers import SGD
from keras.utils import np_utils
from keras import backend as K

# %%
df = pd.read_csv('C:/Users/Lilian/Documents/Projet_deep_learning/g7_SEATGURU_annotate.csv',sep=";")

# %%
df
# Out:
#       Unnamed: 0                                             name format  \
# 0              0  Cathay_Pacific_Airways_Boeing_777-300ER_C_0.jpg    jpg
# 1              1                        KLM_Airbus_A330-300_1.jpg    jpg
# 2              2           American_Airlines_Boeing_767-300_3.jpg    jpg
# 3              3             Air_Canada_Boeing_767-300ER_v2_3.jpg    jpg
# 4              4                     United_Airlines_Q400_A_2.jpg    jpg
# 5              5             American_Airlines_Boeing_787-8_1.jpg    jpg
# 6              6                     Edelweiss_Air_A340-300_0.jpg    jpg
# 7              7                 Etihad_Airways_Airbus_A380_0.jpg    jpg
# 8              8          United_Airlines_Boeing_767_300_ER_1.jpg    jpg
# 9              9                     Iberia_Airbus_A330-200_0.jpg    jpg
# 10            10             China_Eastern_Boeing_777_300ER_0.jpg    jpg
# 11            11                    Oman_Air_Boeing_737-900_3.jpg    jpg
# ...

# %%
def A320():
    liste = []
    for u,v in enumerate(df['name']):
        if df['aircraft_type'][u]=='A320' and df['view'][u]=='Int':
            liste.append(v)
    return liste
    
A320 = A320()

# %%
def A330():
    liste = []
    for u,v in enumerate(df['name']):
        if df['aircraft_type'][u]=='A330' and df['view'][u]=='Int':
            liste.append(v)
    return liste
    
A330 = A330()

# %%
def A350():
    liste = []
    for u,v in enumerate(df['name']):
        if df['aircraft_type'][u]=='A350' and df['view'][u]=='Int':
            liste.append(v)
    return liste
    
A350 = A350()

# %%
def A380():
    liste = []
    for u,v in enumerate(df['name']):
        if df['aircraft_type'][u]=='A380' and df['view'][u]=='Int':
            liste.append(v)
    return liste
    
A380 = A380()

# %%
def B737():
    liste = []
    for u,v in enumerate(df['name']):
        if df['aircraft_type'][u]=='737' and df['view'][u]=='Int':
            liste.append(v)
    return liste
    
B737 = B737()

# %%
def B747():
    liste = []
    for u,v in enumerate(df['name']):
        if df['aircraft_type'][u]=='747' and df['view'][u]=='Int':
            liste.append(v)
    return liste
    
B747 = B747()

# %%
def B757():
    liste = []
    for u,v in enumerate(df['name']):
        if df['aircraft_type'][u]=='757' and df['view'][u]=='Int':
            liste.append(v)
    return liste
    
B757 = B757()

# %%
def B777():
    liste = []
    for u,v in enumerate(df['name']):
        if df['aircraft_type'][u]=='777' and df['view'][u]=='Int':
            liste.append(v)
    return liste
    
B777 = B777()

# %%
airbus_planes = ['A320', 'A330', 'A350', 'A380']
boeing_planes = ['737', '747', '757', '777']

path = 'C:/Users/Lilian/Documents/Projet_deep_learning/SEATGURU'
for plane in airbus_planes:
        os.makedirs(path + '/Airbus/' + plane)
        
for plane in boeing_planes:
        os.makedirs(path + '/Boeing/' + plane)

# %%
path = 'C:/Users/Lilian/Documents/Projet_deep_learning/Interpromo2020/All Data/ANALYSE IMAGE/IMG SEATGURU/'
path2 = 'C:/Users/Lilian/Documents/Projet_deep_learning/SEATGURU/Airbus/A320/'
for pict in A320 :
    copyfile(path + pict, path2 + pict)

# %%
path2 = 'C:/Users/Lilian/Documents/Projet_deep_learning/SEATGURU/Airbus/A330/'
for pict in A330 :
    copyfile(path + pict, path2 + pict)

# %%
path2 = 'C:/Users/Lilian/Documents/Projet_deep_learning/SEATGURU/Airbus/A350/'
for pict in A350 :
    copyfile(path + pict, path2 + pict)

# %%
path2 = 'C:/Users/Lilian/Documents/Projet_deep_learning/SEATGURU/Airbus/A380/'
for pict in A380 :
    copyfile(path + pict, path2 + pict)

# %%
path2 = 'C:/Users/Lilian/Documents/Projet_deep_learning/SEATGURU/Boeing/737/'
for pict in B737 :
    copyfile(path + pict, path2 + pict)

# %%
path2 = 'C:/Users/Lilian/Documents/Projet_deep_learning/SEATGURU/Boeing/747/'
for pict in B747 :
    copyfile(path + pict, path2 + pict)

# %%
path2 = 'C:/Users/Lilian/Documents/Projet_deep_learning/SEATGURU/Boeing/757/'
for pict in B757 :
    copyfile(path + pict, path2 + pict)

# %%
path2 = 'C:/Users/Lilian/Documents/Projet_deep_learning/SEATGURU/Boeing/777/'
for pict in B777 :
    copyfile(path + pict, path2 + pict)

# %%
def sep_train_test(new_paths = ['C:/Users/Lilian/Documents/Projet_deep_learning/Split_data/SEATGURU/Train', 'C:/Users/Lilian/Documents/Projet_deep_learning/Split_data/SEATGURU/Validation'], path = 'C:/Users/Lilian/Documents/Projet_deep_learning/SEATGURU', airbus_planes = ['A320', 'A330', 'A350', 'A380'], boeing_planes = ['737', '747', '757', '777'], split_limite = .8):
    for plane in airbus_planes:
        os.makedirs(new_paths[0] + '/' + plane)
        os.makedirs(new_paths[1] + '/' + plane)
        
        for pict in os.listdir(path + '/Airbus/' + plane):
            rand = np.random.random()
            if rand <= split_limite:
                copyfile(path + '/Airbus/' + plane + '/' + pict, new_paths[0] + '/' + plane + '/' + pict)
            else:
                copyfile(path + '/Airbus/' + plane + '/' + pict, new_paths[1] + '/' + plane + '/' + pict)
                
    for plane in boeing_planes:
        os.makedirs(new_paths[0] + '/' + plane)
        os.makedirs(new_paths[1] + '/' + plane)
        
        for pict in os.listdir(path + '/Boeing/' + plane):
            rand = np.random.random()
            if rand <= split_limite:
                copyfile(path + '/Boeing/' + plane + '/' + pict, new_paths[0] + '/' + plane + '/' + pict)
            else:
                copyfile(path + '/Boeing/' + plane + '/' + pict, new_paths[1] + '/' + plane + '/' + pict)

# %%
sep_train_test()

# %%
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
train_generator = train_datagen.flow_from_directory('C:/Users/Lilian/Documents/Projet_deep_learning/Split_data/SEATGURU/Train',
                                                 target_size=(224,224),
                                                 color_mode='rgb',
                                                 batch_size=32,
                                                 class_mode='categorical',
                                                 shuffle=True)
# Out:
# Found 877 images belonging to 8 classes.

# %%
test_generator = train_datagen.flow_from_directory('C:/Users/Lilian/Documents/Projet_deep_learning/Split_data/SEATGURU/Validation',
                                                 target_size=(224,224),
                                                 color_mode='rgb',
                                                 batch_size=32,
                                                 class_mode='categorical',
                                                 shuffle=True)
# Out:
# Found 199 images belonging to 8 classes.

# %%
def create_model(input_shape = (128,128,3), nb_couches = 3, nb_neuronnes = 10, kernel = (3,3), pool = (2, 2), nb_classes = 1):
    model = Sequential()
    
    model.add(InputLayer(input_shape=input_shape))
    
    for i in range(nb_couches):
        model.add(Conv2D(2**(nb_neuronnes + i), kernel_size=kernel))
        model.add(keras.layers.BatchNormalization())
        model.add(ReLU())

        model.add(Conv2D(2**(nb_neuronnes + i), kernel_size=kernel))
        model.add(keras.layers.BatchNormalization())
        model.add(ReLU())
        
        if i>1:
            model.add(Conv2D(2**(nb_neuronnes + i), kernel_size=kernel))
            model.add(keras.layers.BatchNormalization())
            model.add(ReLU())
        
        model.add(MaxPooling2D(pool_size=pool))

    model.add(Flatten())

    model.add(Dense(1024))
    model.add(keras.layers.BatchNormalization())
    model.add(ReLU())
    
    model.add(Dense(512))
    model.add(keras.layers.BatchNormalization())
    model.add(ReLU())
    
    model.add(Dense(nb_classes, activation='softmax'))

    model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

    return model

# %%
model = create_model(input_shape = (224,224,3), nb_couches = 4, nb_neuronnes = 4, nb_classes = 8)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_18 (Conv2D)           (None, 222, 222, 16)      448
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 222, 222, 16)      64
# _________________________________________________________________
# re_lu_22 (ReLU)              (None, 222, 222, 16)      0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 220, 220, 16)      2320
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 220, 220, 16)      64
# _________________________________________________________________
# re_lu_23 (ReLU)              (None, 220, 220, 16)      0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 110, 110, 16)      0
# ...

# %%
step_size_train = train_generator.n // train_generator.batch_size
epochs = 5

# Lancement de l'entraînement
model.fit_generator(train_generator,
                              steps_per_epoch = step_size_train,
                              epochs=epochs,
                              validation_data=test_generator,
                   validation_steps=len(test_generator))
# Out:
# Epoch 1/5
# 27/27 [==============================] - 874s 32s/step - loss: 2.2490 - acc: 0.2523 - val_loss: 7.4540 - val_acc: 0.2211
# Epoch 2/5
# 27/27 [==============================] - 837s 31s/step - loss: 1.6839 - acc: 0.3892 - val_loss: 2.3660 - val_acc: 0.2714
# Epoch 3/5
# 27/27 [==============================] - 831s 31s/step - loss: 1.3937 - acc: 0.4921 - val_loss: 2.1080 - val_acc: 0.2312
# Epoch 4/5
# 27/27 [==============================] - 10608s 393s/step - loss: 1.1319 - acc: 0.5984 - val_loss: 2.2273 - val_acc: 0.2513
# Epoch 5/5
# 27/27 [==============================] - 404s 15s/step - loss: 0.7655 - acc: 0.7395 - val_loss: 2.2142 - val_acc: 0.2563
