# %% [markdown]
# Created on Sun Jan 12 00:00:10 2020
# <br>
# Group 7
# <br>
# @author: C.L.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import numpy as np
from matplotlib.pyplot import imread
import os

# %%
path = 'Interpromo2020/All Data/ANALYSE IMAGE/SEATGURU/ext-int/'

# %%
list_doc = os.listdir(path)

# %%
list_doc
# Out:
# ['.DS_Store',
#  'Aegean_Airlines_Airbus_A320-200_4.jpg',
#  'Aer_Lingus_Airbus_A320_0.jpg',
#  'Aer_Lingus_Airbus_A330-200_3.jpg',
#  'Aer_Lingus_Airbus_A330-300_A_0.jpg',
#  'Aeroflot_Russian_Airlines_Airbus_A320_V2_0.jpg',
#  'Aeroflot_Russian_Airlines_Airbus_A320_V2_2.jpg',
#  'Aeroflot_Russian_Airlines_Airbus_A320_V2_3.jpg',
#  'Aeroflot_Russian_Airlines_Airbus_A320_V2_4.jpg',
#  'Aeroflot_Russian_Airlines_Airbus_A321_2.jpg',
#  'Aerolineas_Argentinas_Boeing_737-700_1.jpg',
#  'AeroMexico_Boeing_737-700_V2_3.jpg',
#  'AeroMexico_Embraer_ERJ-190_4.jpg',
#  'AeroMexio_Boeing_787-8_0.jpg',
#  'AeroMexio_Boeing_787-8_1.jpg',
#  'AeroMexio_Boeing_787-8_2.jpg',
#  'AeroMexio_Boeing_787-8_3.jpg',
#  'Air_Asia_Airbus_320_1.jpg',
#  'Air_Asia_Airbus_320_2.jpg',
#  'Air_Asia_Airbus_320_3.jpg',
#  'Air_Canada_AC_Boeing_737_MAX_8_0.jpg',
#  'Air_Canada_Embraer_175_4.jpg',
#  'Air_Canada_Embraer_190_1.jpg',
#  'Air_China_Airbus_A321_4.jpg',
# ...

# %%
df = pd.DataFrame(columns=['Picture name', 'View'])

# %%
df['Picture name'] = list_doc
df['View'] = 'Ext-Int'

# %%
df
# Out:
#                                         Picture name     View
# 0                                          .DS_Store  Ext-Int
# 1              Aegean_Airlines_Airbus_A320-200_4.jpg  Ext-Int
# 2                       Aer_Lingus_Airbus_A320_0.jpg  Ext-Int
# 3                   Aer_Lingus_Airbus_A330-200_3.jpg  Ext-Int
# 4                 Aer_Lingus_Airbus_A330-300_A_0.jpg  Ext-Int
# 5     Aeroflot_Russian_Airlines_Airbus_A320_V2_0.jpg  Ext-Int
# 6     Aeroflot_Russian_Airlines_Airbus_A320_V2_2.jpg  Ext-Int
# 7     Aeroflot_Russian_Airlines_Airbus_A320_V2_3.jpg  Ext-Int
# 8     Aeroflot_Russian_Airlines_Airbus_A320_V2_4.jpg  Ext-Int
# 9        Aeroflot_Russian_Airlines_Airbus_A321_2.jpg  Ext-Int
# 10        Aerolineas_Argentinas_Boeing_737-700_1.jpg  Ext-Int
# 11                AeroMexico_Boeing_737-700_V2_3.jpg  Ext-Int
# 12                  AeroMexico_Embraer_ERJ-190_4.jpg  Ext-Int
# 13                      AeroMexio_Boeing_787-8_0.jpg  Ext-Int
# ...

# %%
df.to_csv(path + '/SEATGURU.csv', sep=';', index=False)
